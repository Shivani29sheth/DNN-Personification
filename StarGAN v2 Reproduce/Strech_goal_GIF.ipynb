# %%
# Import libraries
import cv2
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
# Reference image
img = cv2.imread('23.jpg')

# %%
img.shape
# Out:
# (768, 2816, 3)

# %%
cv2_imshow(img[512 : 768, 256:512])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E8FB4F690>

# %%
x = 256
y = 512
k  = 220
for i in range(7):
  img3 = img[512 : 768, x : y]
  print(k)
  k += 1
  cv2_imshow(img3)
  cv2.imwrite(str(k)+'.jpg', img3)
  x = x + 256
  y = y + 256
# Out:
# 220
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E9027BF50>
# 221
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E8FBF7C10>
# 222
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E9027BF50>
# 223
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E8FB4F2D0>
# 224
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E9027BF50>
# 225
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E8FBF70D0>
# 226
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8E8FBF7150>

# %%
# !cp -rf /content/*jpg /content/Output/

# %%
# !rm -rf *jpg

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	Output	sample_data

# %%
# !ls gdrive
# Out:
# MyDrive

# %%
# !cp -r Output/ gdrive/MyDrive/

# %%
# !ls gdrive/MyDrive/Output/
# Out:
# 100.jpg  124.jpg   147.jpg  170.jpg  194.jpg  217.jpg  35.jpg  59.jpg  82.jpg
# 101.jpg  125.jpg   148.jpg  171.jpg  195.jpg  218.jpg  36.jpg  5.jpg   83.jpg
# 102.jpg  126.jpg   149.jpg  172.jpg  196.jpg  219.jpg  37.jpg  60.jpg  84.jpg
# 103.jpg  127.jpg   14.jpg   173.jpg  197.jpg  21.jpg   38.jpg  61.jpg  85.jpg
# 104.jpg  128.jpg   150.jpg  174.jpg  198.jpg  220.jpg  39.jpg  62.jpg  86.jpg
# 105.jpg  129.jpg   151.jpg  175.jpg  199.jpg  221.jpg  3.jpg   63.jpg  87.jpg
# 106.jpg  12.jpg    152.jpg  176.jpg  19.jpg   222.jpg  40.jpg  64.jpg  88.jpg
# 107.jpg  12th.jpg  153.jpg  177.jpg  1.jpg    223.jpg  41.jpg  65.jpg  89.jpg
# 108.jpg  130.jpg   154.jpg  178.jpg  200.jpg  224.jpg  42.jpg  66.jpg  8.jpg
# 109.jpg  131.jpg   155.jpg  179.jpg  201.jpg  225.jpg  43.jpg  67.jpg  90.jpg
# 10.jpg	 132.jpg   156.jpg  17.jpg   202.jpg  226.jpg  44.jpg  68.jpg  91.jpg
# 110.jpg  133.jpg   157.jpg  180.jpg  203.jpg  227.jpg  45.jpg  69.jpg  92.jpg
# ...
